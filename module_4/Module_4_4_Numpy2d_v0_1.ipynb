# %% [markdown]
# <a href="https://colab.research.google.com/github/harshnavadiya/dsmltrainer/blob/master/module_4/Module_4_4_Numpy2d_v0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #numpy in Python

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
#  Consider the list **a **, the list contains three nested lists **each of equal size**.

# %%
a=[[11,12,13],[21,22,23],[31,32,33]]
a
# Out:
# [[11, 12, 13], [21, 22, 23], [31, 32, 33]]

# %% [markdown]
#  We can cast the list to a numpy array  as follow

# %%
#every elment if of the same type 
A=np.array(a)
A
# Out:
# array([[11, 12, 13],
#        [21, 22, 23],
#        [31, 32, 33]])

# %% [markdown]
# We can use the attribute **ndim** to obtain the number of axes or dimensions referred to as the rank.

# %%
A.ndim
# Out:
# 2

# %% [markdown]
#  Attribute **shape** returns a tuple corresponding to the size or number of each dimension.

# %%
A.shape
# Out:
# (3, 3)

# %% [markdown]
# The total number of elements in the array is given by the attribute **size**.

# %%
A.size
# Out:
# 9

# %% [markdown]
# ### Accessing different elements of an Numpy Array

# %% [markdown]
#  We can use rectangular brackets to access the different elements of the array,The correspondence  between the rectangular brackets and the list and the rectangular representation is shown in the following figure for a 3x3 array:

# %% [markdown]
#  <a><img src = "https://ibm.box.com/shared/static/dsa3nfspbvarlwikt2nuva4ka8ez7stm.png" width = 500, align = "center"></a>

# %% [markdown]
# We can access the 2nd-row 3rd column as shown in the following figure:

# %%
from IPython.display import Image, display
display(Image('https://ibm.box.com/shared/static/7ezznbkz63cvd39wn6yidqojdqbh9v0u.png'))

# %% [markdown]
#  We simply use the square brackets and the indices corresponding to the element we would like:

# %%
A[1,2]
# Out:
# 23

# %% [markdown]
#  We can also use the following notation to obtain the elements:

# %%
A[1][2]
# Out:
# 23

# %% [markdown]
#  Consider the elements shown in the following figure

# %%
from IPython.display import Image, display
display(Image('https://ibm.box.com/shared/static/178texrln4qv2figweqtmgliwwikncnd.png'))

# %% [markdown]
#  we can access the element as follows

# %%
A[0][0]
# Out:
# 11

# %% [markdown]
#  We can also use slicing in numpy arrays,consider the following figure; we would like to obtain the first two columns in the first row

# %%
from IPython.display import Image, display
display(Image('https://ibm.box.com/shared/static/mjmlvk9d9p1fokh5e1ka51bayw8qnv1e.png'))

# %% [markdown]
#  This can be done with the following syntax

# %%
 A[0][0:2]
# Out:
# array([11, 12])

# %% [markdown]
# Similarly, we can obtain the first two rows of the 3rd column as follows:

# %%
A[0:2,2]
# Out:
# array([12, 22])

# %% [markdown]
# Corresponding to the following figure:

# %%
from IPython.display import Image, display
display(Image('https://ibm.box.com/shared/static/p9y7q111sq4epvkn2vtvkda5667gyiho.png'))

# %% [markdown]
# # Basic Operations

# %% [markdown]
#  We can also add arrays; the process is identical to matrix addition. Matrix addition of **X** and **Y** is shown in the following figure:

# %%
from IPython.display import Image, display
display(Image('https://ibm.box.com/shared/static/6fiwxq3nsnpk3ae82t0vbxv8qtz1c1gs.png'))

# %% [markdown]
#  The numpy array is given by **X** and **Y**

# %%
X=np.array([[1,0],[0,1]]) 
X
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
Y=np.array([[2,1],[1,2]]) 
Y
# Out:
# array([[2, 1],
#        [1, 2]])

# %% [markdown]
#  We can add the numpy arrays as follows.

# %%
Z=X+Y
Z
# Out:
# array([[3, 1],
#        [1, 3]])

# %% [markdown]
#  Multiplying a numpy array by a scaler is identical to multiplying a matrix by a scaler. If we multiply the matrix **Y** by the scaler 2, we simply multiply every element in the matrix by 2 as shown in the figure.

# %%
from IPython.display import Image, display
display(Image('https://ibm.box.com/shared/static/b942bzigx47l3bfkielh0d36ghurrma8.png'))

# %% [markdown]
#  We can perform the same operation in numpy as follows

# %%
Y=np.array([[2,1],[1,2]]) 
Y
# Out:
# array([[2, 1],
#        [1, 2]])

# %%
Z=2*Y
Z
# Out:
# array([[4, 2],
#        [2, 4]])

# %% [markdown]
#  Multiplication of two arrays corresponds to an element-wise product or  Hadamard product.  Consider matrix  **X** and **Y**. The Hadamard product corresponds to multiplying each of the elements in the same position, i.e. multiplying elements contained in the same colour boxes together. The result is a new matrix that is the same size as matrix **Y** or **X**, as shown in the following figure.

# %%
from IPython.display import Image, display
display(Image('https://ibm.box.com/shared/static/7yha01bj0orozx9vicpf32p6p4t3f3ii.png'))

# %% [markdown]
# We can perform element-wise product of the array **X** and **Y** as follows:

# %%
Y=np.array([[2,1],[1,2]]) 
Y
# Out:
# array([[2, 1],
#        [1, 2]])

# %%
X=np.array([[1,0],[0,1]]) 
X
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
Z=X*Y
Z
# Out:
# array([[2, 0],
#        [0, 2]])

# %% [markdown]
#  We can also perform matrix multiplication with the numpy arrays **A** and **B** as follows:

# %% [markdown]
#  First, we define matrix **A** and **B**:

# %%
A=np.array([[0,1,1],[1,0,1]])
A
# Out:
# array([[0, 1, 1],
#        [1, 0, 1]])

# %%
B=np.array([[1,1],[1,1],[-1,1]])
B
# Out:
# array([[ 1,  1],
#        [ 1,  1],
#        [-1,  1]])

# %% [markdown]
# We use the numpy function **dot** to multiply the arrays together.

# %%
Z=np.dot(A,B)
Z
# Out:
# array([[0, 2],
#        [0, 2]])

# %%
np.sin(Z)
# Out:
# array([[ 0.90929743,  0.        ],
#        [ 0.        ,  0.90929743]])

# %%
C=np.array([[1,1],[2,2],[3,3]])
C
# Out:
# array([[1, 1],
#        [2, 2],
#        [3, 3]])

# %%
C.T
# Out:
# array([[1, 2, 3],
#        [1, 2, 3]])
